# %%
# from sklearn.datasets import load_boston

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train.drop("Id", axis = 1, inplace = True)

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
train["ExterCond"].unique()
# Out:
# array(['TA', 'Gd', 'Fa', 'Po', 'Ex'], dtype=object)

# %%
train = train[['LotFrontage',
 'LotArea',
 'Street',
 'Alley',
 'LotShape',
 'LandContour',
 'Utilities',
 'LotConfig',
 'LandSlope',
 'Neighborhood',
 'HouseStyle',
 'YearBuilt',
 'YearRemodAdd',
 'RoofStyle',
 'GarageArea',
 'GarageQual',
 'GarageCond',
 'PavedDrive',
 'ScreenPorch',
 'PoolArea',
 'YrSold',
 'SaleType',
 'SaleCondition',
 'SalePrice']]

# %%
train
# Out:
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 0            65.0     8450   Pave   NaN      Reg         Lvl    AllPub
# 1            80.0     9600   Pave   NaN      Reg         Lvl    AllPub
# 2            68.0    11250   Pave   NaN      IR1         Lvl    AllPub
# 3            60.0     9550   Pave   NaN      IR1         Lvl    AllPub
# 4            84.0    14260   Pave   NaN      IR1         Lvl    AllPub
# ...           ...      ...    ...   ...      ...         ...       ...
# 1455         62.0     7917   Pave   NaN      Reg         Lvl    AllPub
# 1456         85.0    13175   Pave   NaN      Reg         Lvl    AllPub
# 1457         66.0     9042   Pave   NaN      Reg         Lvl    AllPub
# 1458         68.0     9717   Pave   NaN      Reg         Lvl    AllPub
# 1459         75.0     9937   Pave   NaN      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageArea  GarageQual  GarageCond  \
# ...

# %%
train["LotFrontage"].describe()[0]
# Out:
# 1201.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1201 non-null   float64
#  1   LotArea        1460 non-null   int64
#  2   Street         1460 non-null   object
#  3   Alley          91 non-null     object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  YearBuilt      1460 non-null   int64
#  12  YearRemodAdd   1460 non-null   int64
#  13  RoofStyle      1460 non-null   object
#  14  GarageArea     1460 non-null   int64
#  15  GarageQual     1379 non-null   object
#  16  GarageCond     1379 non-null   object
# ...

# %%
cols = []
for column in train.columns:
    if len(train[train[column].isna() == False]) != 1460:
        cols.append(column)

# %%
train.drop(columns=cols, inplace = True, axis = 1)
# Out:
# /var/folders/6j/0k58mfdd4n77p9l0ggh148rw0000gp/T/ipykernel_6926/22225137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop(columns=cols, inplace = True, axis = 1)

# %%
train
# Out:
#       LotArea Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0        8450   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1        9600   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       11250   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3        9550   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       14260   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455     7917   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456    13175   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457     9042   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458     9717   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459     9937   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood HouseStyle  YearBuilt  YearRemodAdd RoofStyle  GarageArea  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1460 non-null   int64
#  1   Street         1460 non-null   object
#  2   LotShape       1460 non-null   object
#  3   LandContour    1460 non-null   object
#  4   Utilities      1460 non-null   object
#  5   LotConfig      1460 non-null   object
#  6   LandSlope      1460 non-null   object
#  7   Neighborhood   1460 non-null   object
#  8   HouseStyle     1460 non-null   object
#  9   YearBuilt      1460 non-null   int64
#  10  YearRemodAdd   1460 non-null   int64
#  11  RoofStyle      1460 non-null   object
#  12  GarageArea     1460 non-null   int64
#  13  PavedDrive     1460 non-null   object
#  14  ScreenPorch    1460 non-null   int64
#  15  PoolArea       1460 non-null   int64
#  16  YrSold         1460 non-null   int64
# ...

# %%
# hw convert above for loop into list comprehension
# find number of NaN values in each column, replace those NaN values with the mean of the column
# try to plot the bar graph of the sales price with respect to years sold (Yrsold)
# histogram of sales price
